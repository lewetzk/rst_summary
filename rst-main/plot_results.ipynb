# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("classification_result.txt", delimiter="\t",  header=None, usecols=[1,2, 3, 4, 5,6])
data
# Out:
#             1         2         3         4         5         6
# 0         snh    random  baseline  neural50  neural25      gold
# 1         snh  neural25    random  baseline  neural50      gold
# 2      random  baseline       snh      gold  neural50  neural25
# 3      random       snh  baseline      gold  neural25  neural50
# 4         snh  baseline    random  neural50      gold  neural25
# ..        ...       ...       ...       ...       ...       ...
# 168       snh    random  neural50      gold  baseline  neural25
# 169  baseline    random       snh      gold  neural25  neural50
# 170    random       snh  baseline  neural25  neural50      gold
# 171  neural25       snh  neural50    random      gold  baseline
# 172       snh    random  baseline  neural50      gold  neural25
#
# [173 rows x 6 columns]

# %%
types = ["random", "baseline", "snh", "gold", "neural25", "neural50"]

# %%
ddict = {
    1: dict(),
    2: dict(),
    3: dict(),
    4: dict(),
    5: dict(),
    6: dict(),
}

# %%
for i in range(6):
    for t in types:
        ddict[i+1][t] = (data[i+1] == t).sum()

# %%
ddict
# Out:
# {1: {'random': 79,
#   'baseline': 4,
#   'snh': 41,
#   'gold': 1,
#   'neural25': 28,
#   'neural50': 20},
#  2: {'random': 44,
#   'baseline': 37,
#   'snh': 27,
#   'gold': 3,
#   'neural25': 32,
#   'neural50': 30},
#  3: {'random': 28,
#   'baseline': 48,
#   'snh': 24,
#   'gold': 7,
#   'neural25': 31,
#   'neural50': 35},
#  4: {'random': 19,
#   'baseline': 34,
#   'snh': 29,
#   'gold': 31,
#   'neural25': 29,
#   'neural50': 31},
#  5: {'random': 3,
#   'baseline': 40,
#   'snh': 24,
#   'gold': 45,
#   'neural25': 30,
#   'neural50': 31},
#  6: {'random': 0,
#   'baseline': 10,
#   'snh': 28,
#   'gold': 86,
#   'neural25': 23,
#   'neural50': 26}}

# %%
to_plot = pd.DataFrame(ddict)

# %%
to_plot.T.plot.line(figsize=(20, 15), linewidth=8)
plt.legend(types, ncol=3, loc='upper right')
plt.xlabel('ORDER 1(WORST) - 6 (BEST)', fontsize=18)
plt.ylabel('FREQUENCY', fontsize=16)
plt.xticks(fontsize=20, rotation=0)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
